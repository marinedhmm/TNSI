# %% [markdown]
# # 1 Afficher le repertoire courant
# ```bash
# pwd
# ```
# # 2 Remonter dans le repertoire /home/vscode
# ```bash
# cd ../../../home/vscode
# cd /home/vscode
# ```
# # 3 Créer un dossier miniTP dans ce répertoire
# ```bash
# mkdir miniTP
# ```
# # 4 Afficher le contenu de tous les fichiers ou dossiers présents
# ```bash
# ls -la
# ```
# # 5 créer un fichier vide notes.txt
# ```bash
# touch notes.txt
# ```
# # 6 Ajouter dans ce fichier la ligne "Linux is Powerful"
# ```bash
# nano ./notes.txt
# echo "Linux is Powerfull" > ./notes.txt
# ```
# La redirection avec `>>` permet d'ajouter sans écraser le contenu existant.
# # 7 renommer ce fichier sans le déplacer en notes_backup.txt
# ```bash
# mv ./notes.txt ./notes_backup.txt
# ```
# # 8 copier ce fichier dans le dossier cours de votre workspace
# ```bash
# cp ./notes_backup.txt /workspaces/TNSI/Cours/notes_backup.txt
# ```
# # 9 compter le nombre de mot dans le fichier
# ```bash
#
# ```
# # 10 afficher le/les lignes avec le mot powerful dans la console
# ```bash
#
# ```
